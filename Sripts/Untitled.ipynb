# %%
import pandas as pd
df1 = pd.read_csv("D:/Postulacion-Telefonica/Data/yellowtot_1.csv")

# %%
df1.head()
# Out:
#    yellowtot_1.vendorid yellowtot_1.tpep_pickup_datetime  \
# 0                     2              2015-09-14 10:25:20
# 1                     2              2015-09-03 07:10:14
# 2                     2              2015-09-03 07:49:18
# 3                     2              2015-09-12 08:47:54
# 4                     1              2015-09-10 07:20:41
#
#   yellowtot_1.tpep_dropoff_datetime  yellowtot_1.passenger_count  \
# 0               2015-09-14 10:29:52                            2
# 1               2015-09-03 07:21:52                            1
# 2               2015-09-03 08:08:52                            1
# 3               2015-09-12 08:53:46                            5
# 4               2015-09-10 07:25:59                            1
#
#    yellowtot_1.trip_distance  yellowtot_1.pickup_longitude  \
# 0                       0.67                     -73.96322
# 1                       0.83                     -73.98021
# ...
